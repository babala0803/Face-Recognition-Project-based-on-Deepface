# %%
import os
import shutil

def copy_and_rename_images(source_folders, destination_folder):
    for folder in source_folders:
        folder_name = os.path.basename(folder)
        image_files = os.listdir(folder)[:3]
        
        for i, image_file in enumerate(image_files):
            source_path = os.path.join(folder, image_file)
            new_filename = f"{folder_name}_{i+1}{os.path.splitext(image_file)[1]}"
            destination_path = os.path.join(destination_folder, new_filename)
            
            shutil.copy(source_path, destination_path)

# 要复制图片的源文件夹列表
source_folders = ['./vggface2/n000029', './vggface2/n000078', './vggface2/n000129',
                './vggface2/n000480', './vggface2/n000659', './vggface2/n000740', './vggface2/n000785',
                './vggface2/n000912', './vggface2/n001021', './vggface2/n001146', './vggface2/n001190',
                 './vggface2/n001197', './vggface2/n001211', './vggface2/n001242', './vggface2/n001368',
                  './vggface2/n001485',  './vggface2/n001683', './vggface2/n001687', './vggface2/n001817',
                  './vggface2/n001830','./vggface2/n001857','./vggface2/n001934',
                  './vggface2/n002024', './vggface2/n002475', './vggface2/n002503', './vggface2/n002561',
                  './vggface2/n002581','./vggface2/n002659','./vggface2/n002775','./vggface2/n002838',
                  './vggface2/n002891', './vggface2/n003079']

# 目标文件夹路径
destination_folder = './testset1'

# 创建目标文件夹
os.makedirs(destination_folder, exist_ok=True)

# 复制并重命名图片
copy_and_rename_images(source_folders, destination_folder)

# %%
import os
import shutil

def copy_and_rename_images(source_folders, destination_folder):
    for folder in source_folders:
        folder_name = os.path.basename(folder)
        image_files = os.listdir(folder)[3:6]
        
        for i, image_file in enumerate(image_files):
            source_path = os.path.join(folder, image_file)
            new_filename = f"{folder_name}_{i+4}{os.path.splitext(image_file)[1]}"
            destination_path = os.path.join(destination_folder, new_filename)
            
            shutil.copy(source_path, destination_path)

# 要复制图片的源文件夹列表
source_folders = ['./vggface2/n000029', './vggface2/n000078', './vggface2/n000129',
                './vggface2/n000480', './vggface2/n000659', './vggface2/n000740', './vggface2/n000785',
                './vggface2/n000912', './vggface2/n001021', './vggface2/n001146', './vggface2/n001190',
                 './vggface2/n001197', './vggface2/n001211', './vggface2/n001242', './vggface2/n001368',
                  './vggface2/n001485',  './vggface2/n001683', './vggface2/n001687', './vggface2/n001817',
                  './vggface2/n001830','./vggface2/n001857','./vggface2/n001934',
                  './vggface2/n002024', './vggface2/n002475', './vggface2/n002503', './vggface2/n002561',
                  './vggface2/n002581','./vggface2/n002659','./vggface2/n002775','./vggface2/n002838',
                  './vggface2/n002891', './vggface2/n003079']

# 目标文件夹路径
destination_folder = './testset2'

# 创建目标文件夹
os.makedirs(destination_folder, exist_ok=True)

# 复制并重命名图片
copy_and_rename_images(source_folders, destination_folder)

# %%
import os
import shutil

def copy_and_rename_images(source_folders, destination_folder):
    for folder in source_folders:
        folder_name = os.path.basename(folder)
        image_files = os.listdir(folder)[:2]
        
        for i, image_file in enumerate(image_files):
            source_path = os.path.join(folder, image_file)
            new_filename = f"{folder_name}_{i+1}{os.path.splitext(image_file)[1]}"
            destination_path = os.path.join(destination_folder, new_filename)
            
            shutil.copy(source_path, destination_path)

# 要复制图片的源文件夹列表
source_folders = ['./Faces/Actor', './Faces/Football Player', './Faces/Scientist']

# 目标文件夹路径
destination_folder = './add_testset1'

# 创建目标文件夹
os.makedirs(destination_folder, exist_ok=True)

# 复制并重命名图片
copy_and_rename_images(source_folders, destination_folder)

# %%
import os
import shutil

def copy_and_rename_images(source_folders, destination_folder):
    for folder in source_folders:
        folder_name = os.path.basename(folder)
        image_files = os.listdir(folder)[2:5]
        
        for i, image_file in enumerate(image_files):
            source_path = os.path.join(folder, image_file)
            new_filename = f"{folder_name}_{i+3}{os.path.splitext(image_file)[1]}"
            destination_path = os.path.join(destination_folder, new_filename)
            
            shutil.copy(source_path, destination_path)

# 要复制图片的源文件夹列表
source_folders = ['./vggface2/n000029', './vggface2/n000078', './vggface2/n000129',
                './vggface2/n000480', './vggface2/n000659', './vggface2/n000740', './vggface2/n000785',
                './vggface2/n000912', './vggface2/n001021', './vggface2/n001146', './vggface2/n001190',
                 './vggface2/n001197', './vggface2/n001211', './vggface2/n001242', './vggface2/n001368',
                  './vggface2/n001485',  './vggface2/n001683', './vggface2/n001687', './vggface2/n001817',
                  './vggface2/n001830','./vggface2/n001857','./vggface2/n001934',
                  './vggface2/n002024', './vggface2/n002475', './vggface2/n002503', './vggface2/n002561',
                  './vggface2/n002581','./vggface2/n002659','./vggface2/n002775','./vggface2/n002838',
                  './vggface2/n002891', './vggface2/n003079', './Faces/Actor', './Faces/Football Player', './Faces/Scientist']

# 目标文件夹路径
destination_folder = './add_testset2'

# 创建目标文件夹
os.makedirs(destination_folder, exist_ok=True)

# 复制并重命名图片
copy_and_rename_images(source_folders, destination_folder)
