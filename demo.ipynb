# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
from deepface.commons import distance as dst
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
import matplotlib.gridspec as gridspec
import matplotlib.patches as patches
import numpy as np

# %%
# resp1 = DeepFace.verify(img1_path='./testset1/n0000293.jpg', img2_path='./testset2/n0000297.jpg', model_name='Facenet')

# %%
# df = DeepFace.find(img_path='./testset1/n000029_1.jpg', db_path='./testset2/', enforce_detection=False)

# %%
# df[0]

# %%
def get_file_paths(directory):
    file_paths = []  # 存储文件路径的列表

    # 获取文件夹内的所有文件和文件夹
    items = os.listdir(directory)

    # 遍历每个项目
    for item in items:
        item_path = os.path.join(directory, item)  # 构建项目的完整路径

        # 检查是否为文件
        if os.path.isfile(item_path):
            file_paths.append(item_path)  # 将文件路径添加到列表中

    return file_paths

folder_path = './testset1/'  # 替换为实际的文件夹路径
file_paths = get_file_paths(folder_path)

# %%
m = 1

df_name = pd.read_csv('./identity.csv', encoding='latin-1')

# 遍历每个项目
for original_img_path in file_paths:
    model_name = 'Facenet'
    distance_metric = 'cosine'
    df = DeepFace.find_all(img_path=original_img_path, db_path='./testset2/', model_name=model_name, distance_metric=distance_metric, enforce_detection=False)
    threshold = dst.findThreshold(model_name, distance_metric)
    result_df = df[0][df[0][f"{model_name}_{distance_metric}"] <= threshold]

    paint_len = np.min([result_df.shape[0], 4])

    result_df = result_df[:paint_len]

    # 创建子图
    fig, axs = plt.subplots(1, len(result_df)+1, figsize=(12, 4))

    # 绘制存储地址对应的图片
    for i, identity in enumerate(result_df['identity']):
        img = Image.open(identity)
        axs[i+1].imshow(img)
        axs[i+1].set_title('Image {}'.format(i+1))

        if i==0:
            predicted_class_id = os.path.splitext(os.path.basename(identity))[0].split('_')[0]
            predicted_name = df_name[df_name['Class_ID'] == predicted_class_id][' Name'].iloc[0]

    axs[0].set_title('Predict: {}'.format(predicted_name))
            

    # 设置图像标题和间距
    fig.suptitle('Comparison of Images', fontsize=16)
    plt.tight_layout()

    # 显示图像
    plt.savefig('add_fig/result_'+str(m)+'_'+str(1)+'.png')
    # plt.show()
    plt.close()

    


    # 计算行数和列数
    num_rows = len(result_df)
    num_cols = 2

    # 创建网格规格
    spec = gridspec.GridSpec(ncols=num_cols, nrows=num_rows, width_ratios=[1, 1])

    # 创建图形对象
    fig = plt.figure(figsize=(6, 4))

    # 绘制原始图片
    img = Image.open(original_img_path)
    ax = fig.add_subplot(spec[:, 0])
    ax.imshow(img, aspect='auto')
    ax.set_title('Predict: {}'.format(predicted_name))

    embeddings = DeepFace.represent(img_path = original_img_path, model_name = model_name, enforce_detection=False)
    # draw a rectangle around the face
    face_coord = embeddings[0]['facial_area']
    rect = patches.Rectangle((face_coord['x'], face_coord['y']), 
                            face_coord['w'], face_coord['h'], 
                            linewidth = 2, 
                            edgecolor = 'r', 
                            facecolor = 'none')

    # add the patch to the axes
    ax.add_patch(rect)

    # 隐藏坐标轴
    ax.axis('off')

    # 绘制存储地址对应的图片
    for i, identity in enumerate(result_df['identity']):
        # img = Image.open(identity)
        img = DeepFace.detectFace(identity)
        ax = fig.add_subplot(spec[i, 1])
        ax.imshow(img)
    
        ax.set_title('Image {} \n dis= {:.3f}'.format(i+1, result_df.iloc[i,-1]), fontsize=8, loc='right')

        # 隐藏坐标轴
        ax.axis('off')

    # 设置图像标题和间距
    fig.suptitle('Comparison of Images', fontsize=14)
    plt.tight_layout()

    # 显示图像
    plt.savefig('fig/result_'+str(m)+'_'+str(2)+'.png')
    # plt.show()
    plt.close()

    m += 1
# Out:
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1406104564666748  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1393449306488037  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1065974235534668  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11570000648498535  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11100125312805176  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10400080680847168  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11299967765808105  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09699892997741699  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11100077629089355  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.14300227165222168  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09500002861022949  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11899256706237793  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12245607376098633  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11358761787414551  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11060667037963867  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10776329040527344  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10699987411499023  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1009523868560791  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11551380157470703  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12999796867370605  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11532235145568848  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10012459754943848  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09400224685668945  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.0970010757446289  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11100220680236816  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12299704551696777  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1080009937286377  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09999942779541016  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09599685668945312  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11300063133239746  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10700011253356934  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12469935417175293  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10957622528076172  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11499953269958496  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11800003051757812  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10600137710571289  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1139986515045166  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11699581146240234  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09858250617980957  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09960603713989258  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1120004653930664  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11504983901977539  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.15061092376708984  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11156368255615234  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.21270108222961426  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.13600444793701172  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.15962696075439453  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.13725805282592773  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10478973388671875  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10399985313415527  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11600255966186523  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.0930023193359375  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09200215339660645  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09560394287109375  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1139974594116211  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12494421005249023  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.0940091609954834  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11581230163574219  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10362982749938965  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11000418663024902  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11361956596374512  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1230020523071289  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12200331687927246  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11500096321105957  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11600017547607422  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10399937629699707  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1289958953857422  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10659217834472656  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12105894088745117  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11157369613647461  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12060236930847168  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11500167846679688  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10399985313415527  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12951278686523438  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09399819374084473  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.14099621772766113  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1095728874206543  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10599899291992188  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.15765953063964844  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11299920082092285  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11699748039245605  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09961867332458496  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09945940971374512  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11399960517883301  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09899640083312988  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1109304428100586  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10207843780517578  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11011266708374023  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11370444297790527  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09599947929382324  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.1380016803741455  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.11099958419799805  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.12518715858459473  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.09839248657226562  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10899829864501953  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# WARNING: Representations for images in ./testset2/ folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  98  representations found in  representations_facenet.pkl
# find function lasts  0.10499882698059082  seconds
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
# ⚠️ Function detectFace is deprecated! Use extract_faces instead of this.
